# %% [markdown]
# Qual gráfico é melhor para detectar outliers univariados?
#
# (a)
# Heatmap
#
# (b)
# Boxplot
#
# (c)
# Histograma
#
# (d)
# Scatter plot
#
# (e)
# Bar plot

# %% [markdown]
# ------
# resposta certa : b)
#
# ------

# %% [markdown]
# Heatmap é útil para detectar:
#
#
# (a)
# Outliers
#
# (b)
# Classes desbalanceadas
#
# (c)
# Distribuição univariada
#
# (d)
# Pares de features altamente correlacionadas
#
# (e)
# Missing values

# %% [markdown]
# ----
# resposta certa: d)
#
# ----

# %% [markdown]
# Principal vantagem do Pipeline:
#
#
# (a)
# Funciona só com regressão
#
# (b)
# Aumenta acurácia
#
# (c)
# Substitui CV
#
# (d)
# Remove necessidade de scaling
#
# (e)
# Evita data leakage em pré-processamento

# %% [markdown]
# -----
# resposta certa: d)
#
# -----

# %% [markdown]
# PCA maximiza:
#
#
# (a)
# Variância explicada
#
# (b)
# Clusters
#
# (c)
# Correlação
#
# (d)
# Distância local
#
# (e)
# Classes

# %% [markdown]
# -----
# resposta certa: a)
#
# -----

# %% [markdown]
# Normalização deve estar:
#
#
# (a)
# Sem fit
#
# (b)
# Antes do modelo no Pipeline
#
# (c)
# No teste primeiro
#
# (d)
# Após o modelo
#
# (e)
# Após CV

# %% [markdown]
# -----
# resposta certa: b)
#
# -----

# %% [markdown]
# random_state garante:
#
#
# (a)
# Menos variância
#
# (b)
# Reprodutibilidade do split
#
# (c)
# Overfitting
#
# (d)
# Melhor split, pois randomiza os exemplares
#
# (e)
# Menos viés, pois randomiza os exemplares

# %% [markdown]
# -----
# resposta certa: b)
#
# -----

# %% [markdown]
# K-Means é sensível a:
#
#
# (a)
# Ordem dos dados
#
# (b)
# Inicialização dos centroides
#
# (c)
# Escala
#
# (d)
# Outliers
#
# (e)
# Todas as acima

# %% [markdown]
# -----
# resposta certa: e)
#
# -----

# %% [markdown]
# Resíduos devem ser:
#
#
# (a)
# Zero
#
# (b)
# Padrão
#
# (c)
# Aleatórios, média zero, variância constante
#
# (d)
# Alta variância
#
# (e)
# Correlacionados

# %% [markdown]
# -----
# resposta certa: c)
#
# -----

# %% [markdown]
# Principal desvantagem do k-fold CV:
#
#
# (a)
# Overfitting garantido
#
# (b)
# Não usa todos os dados
#
# (c)
# Viés alto
#
# (d)
# Não embaralha
#
# (e)
# Custo computacional alto (k vezes mais treino)

# %% [markdown]
# -----
# resposta certa: e)
#
# ------
